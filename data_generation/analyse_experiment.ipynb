# %%
import pandas as pd
import seaborn as sns

# %%
results_df  = pd.read_json("./results/experiment_improved.json").T
results_df.head()
# Out:
#                                                    linear_dim out_channels  \
# model_ld64_oc64_lr0.1_rgclDCRNN_dsdataset_res8_...         64           64
# model_ld64_oc64_lr0.1_rgclTGCN_dsdataset_res8_t...         64           64
# model_ld64_oc64_lr0.1_rgclA3TGCN_dsdataset_res8...         64           64
# model_ld64_oc64_lr0.01_rgclDCRNN_dsdataset_res8...         64           64
# model_ld64_oc64_lr0.01_rgclTGCN_dsdataset_res8_...         64           64
#
#                                                       lr    rgcl  \
# model_ld64_oc64_lr0.1_rgclDCRNN_dsdataset_res8_...   0.1   DCRNN
# model_ld64_oc64_lr0.1_rgclTGCN_dsdataset_res8_t...   0.1    TGCN
# model_ld64_oc64_lr0.1_rgclA3TGCN_dsdataset_res8...   0.1  A3TGCN
# model_ld64_oc64_lr0.01_rgclDCRNN_dsdataset_res8...  0.01   DCRNN
# model_ld64_oc64_lr0.01_rgclTGCN_dsdataset_res8_...  0.01    TGCN
#
#                                                                           ds  \
# ...

# %%
sns.barplot(data=results_df.sort_values("bce"), y="bce", x =results_df.index.values)
# Out:
# <Axes: ylabel='bce'>

# %%
best_model = results_df[results_df["bce"] == results_df["bce"].min()]
best_model
# Out:
#                                                    linear_dim out_channels  \
# model_ld256_oc64_lr0.01_rgclDCRNN_dsdataset_res...        256           64
#
#                                                       lr   rgcl  \
# model_ld256_oc64_lr0.01_rgclDCRNN_dsdataset_res...  0.01  DCRNN
#
#                                                                           ds  \
# model_ld256_oc64_lr0.01_rgclDCRNN_dsdataset_res...  dataset_res8_trajspp6_ev
#
#                                                    epochs    ns       bce  \
# model_ld256_oc64_lr0.01_rgclDCRNN_dsdataset_res...     30  1000  0.006383
#
#                                                    best_threshold    fscore  \
# model_ld256_oc64_lr0.01_rgclDCRNN_dsdataset_res...       0.178261  0.357418
#
#                                                          auc       nvd  \
# model_ld256_oc64_lr0.01_rgclDCRNN_dsdataset_res...  0.263208 -0.341686
#
#                                                          iou  \
# ...

# %%
best_10_models = None
results_df.sort_values("bce", ascending=False).iloc[:10,]
# Out:
#                                                    linear_dim out_channels  \
# model_ld256_oc256_lr0.1_rgclTGCN_dsdataset_res8...        256          256
# model_ld256_oc64_lr0.1_rgclDCRNN_dsdataset_res8...        256           64
# model_ld256_oc64_lr0.1_rgclTGCN_dsdataset_res8_...        256           64
# model_ld256_oc128_lr0.1_rgclTGCN_dsdataset_res8...        256          128
# model_ld128_oc256_lr0.1_rgclTGCN_dsdataset_res8...        128          256
# model_ld128_oc64_lr0.1_rgclDCRNN_dsdataset_res8...        128           64
# model_ld64_oc128_lr0.1_rgclDCRNN_dsdataset_res8...         64          128
# model_ld256_oc256_lr0.1_rgclDCRNN_dsdataset_res...        256          256
# model_ld128_oc128_lr0.1_rgclTGCN_dsdataset_res8...        128          128
# model_ld128_oc256_lr0.1_rgclDCRNN_dsdataset_res...        128          256
#
#                                                      lr   rgcl  \
# model_ld256_oc256_lr0.1_rgclTGCN_dsdataset_res8...  0.1   TGCN
# ...

# %%
df1 = pd.DataFrame({"losses": best_model["train_losses"][0][1:]})
df2 = pd.DataFrame({"losses": best_model["val_losses"][0][:-1]})
best_train_df = pd.concat([df1.assign(source='train'), df2.assign(source='val')])

sns.lineplot(data=best_train_df, y="losses", x =best_train_df.index.values, hue="source")
# Out:
# /var/folders/yn/7x3nb2m93ksflf_b11w8p_mc0000gn/T/ipykernel_17146/31404078.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df1 = pd.DataFrame({"losses": best_model["train_losses"][0][1:]})
# /var/folders/yn/7x3nb2m93ksflf_b11w8p_mc0000gn/T/ipykernel_17146/31404078.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df2 = pd.DataFrame({"losses": best_model["val_losses"][0][:-1]})
# ...

# %%
sns.boxplot(data=results_df, y="bce", x ="out_channels")
# Out:
# /Users/simonzocholl/Desktop/trackgenerator/venv/lib/python3.9/site-packages/seaborn/categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# <Axes: xlabel='out_channels', ylabel='bce'>

# %%
sns.boxplot(data=results_df, y="bce", x ="linear_dim")
# Out:
# /Users/simonzocholl/Desktop/trackgenerator/venv/lib/python3.9/site-packages/seaborn/categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# <Axes: xlabel='linear_dim', ylabel='bce'>

# %%
sns.boxplot(data=results_df, y="bce", x ="lr")
# Out:
# /Users/simonzocholl/Desktop/trackgenerator/venv/lib/python3.9/site-packages/seaborn/categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# <Axes: xlabel='lr', ylabel='bce'>

# %%
sns.boxplot(data=results_df, y="bce", x ="rgcl")
# Out:
# /Users/simonzocholl/Desktop/trackgenerator/venv/lib/python3.9/site-packages/seaborn/categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# <Axes: xlabel='rgcl', ylabel='bce'>

# %%
sns.histplot(data=best_threshold,y="best_threshold")
